# %% [markdown]
# #### Selenium setup

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time


chrome_driver_path = r"C:\Users\Dante Clark\Desktop\chromedriver.exe"

URL = "https://hunterxhunter.fandom.com/wiki/List_of_Volumes_and_Chapters"

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get(URL)

# %% [markdown]
# #### Pandas setup

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 3)

# %% [markdown]
# #### Data appended to arrays

# %%
titles = []
dates = []
# volumes = []

time.sleep(2)

for title in driver.find_elements(By.XPATH, "//td/a"):
    titles.append(title.text)

for date in driver.find_elements(By.XPATH, "//tr//td[3]")[::2]:
    dates.append(date.text)

# for volume in driver.find_elements(By.XPATH, "//tr//td[@colspan=2]//ul//li/a[@title]"):
#     volumes.append(volume.text)
#     print(len(volume.text))

# %% [markdown]
# #### Render dataframe

# %%
data = {
    "title": titles,
    "japanese release": dates
}

df = pd.DataFrame(data=data)

display(df)
# Out:
#                          title                         japanese release
# 0                                 Kurapika's Memories   January 21, 2013
# 1                                The Day of Departure       June 4, 1998
# 2                              A Struggle in the Mist  September 2, 1998
# 3                                          Resolution   November 4, 1998
# 4              End Game (lit. The Final Test Begins!)   February 4, 1999
# 5                  Family Matters (lit. Ging Freecss)     April 30, 1999
# 6                     Nen Sense (lit. Hisoka's Terms)    October 4, 1999
# 7                           Nen Combatant (lit. Next)  December 22, 1999
# 8              The Island (lit. The Auction Begins!!)      April 4, 2000
# 9                  Shadow Beasts (lit. September 1st)       July 4, 2000
# 10  Fakes, Swindles, and the Old Switcheroo (lit. ...   November 2, 2000
# 11  Next Stop: Meteor City—The Junkyard of the Wor...      March 2, 2001
# 12                              September 4th: Part 2       July 4, 2001
# 13                                     September 10th   November 2, 2001
# 14                         The Secret of Greed Island      April 4, 2002
# 15                                           Progress    October 4, 2002
# 16                                           Face-Off   February 4, 2003
# 17                                 Three-Way Struggle       June 4, 2003
# 18                                   Chance Encounter    October 3, 2003
# 19                                                NGL   February 4, 2004
# 20                                           Weakness       June 4, 2004
# 21                                            Reunion   February 4, 2005
# 22                                          8: Part 1       July 4, 2005
# 23                                          6: Part 1      March 3, 2006
# 24                                          1: Part 4    October 4, 2007
# 25                                             Charge      March 4, 2008
# 26                                      We Meet Again    October 3, 2008
# 27                                               Name  December 25, 2009
# 28                                       Regeneration       July 4, 2011
# 29                                             Memory     August 4, 2011
# 30                                             Answer      April 4, 2012
# 31                                   Joining the Fray   December 4, 2012
# 32                                       Total Defeat  December 28, 2012
# 33                                            Threats       June 3, 2016
# 34                                Battle to the Death      June 26, 2017
# 35                     Ship of Fools (lit. Nen Beast)   February 2, 2018
# 36                                            Balance    October 4, 2018
