# %%
import pandas as pd
import seaborn as sns

sns.set_theme()

data = pd.read_csv("./csv_files/raw_data.csv")


sns.histplot(data=data, x="japanese release", bins=37)
# Out:
# <AxesSubplot:xlabel='japanese release', ylabel='Count'>
